# %% [markdown]
# <a href="https://colab.research.google.com/github/Hima19965/hima/blob/main/listtask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'lists'
# a=[1,2,4]
# print(a)
'adding lements'
# v=[21,34,66]
# v.append(100)
# print(v)
'removing an element'
# v=[21,34,66]
# v.remove(66)
# print(v)

'prime numbers'
# n=10
# p=2
# cou=0
# while n>cou:
#     is_prime=True
#     for i in range(2,p):
#         if p%2==0:
#             is_prime=False
#             break
#     if is_prime:
#             print(p)
#             cou+=1
#     p+=1

'amount n = 5200 and breaks it down into the minimum number of currency notes available in denominations of 500, 200, 100, 50, 20, 10, and 1 rupees.'
# n=5200
# f=[500,200,100,50,20,10]
# res=[]
# for x in f:
#     digit=n//x
#     if digit>0:
#         res.append(f'{digit} {x} rupees notes')
#         n%=x
# print(res)

'password checking loop iteration until correct password'

'From a given list of words, extract only those that start with a vowel (a, e, i, o, u).Example words = ["functions", "loops", "oops", "exception","as"]'
# m=['lazy', 'dog', 'barks', 'loops', 'oops']
# res=[i for i in m if i[0] in 'aeiouAEIOU']
# print(res)

'adding numbers in list'
# h=[1,2,3,4]
# k=[5,6,7,8]
# res=[x+y for x in h for y in k]
# print(res)

'printing primes after adding numbers in list'
# h=[1,2,3]
# k=[4,5,6]
# res=[h[x]+k[x] for x in range(len(h))]
# print(res)

'primes from 11 to 20 xxxxxxxx'
# for x in range(10,21):
#   for y in range(2,10):
#         if x%y==0:
#             break
#         else:
#          print(x)

'primes from 11 to 20'
# res= [x for x in range(10,20) if all(x%y!=0 for y in range(2,x))]
# print(res)
'reversing strings in list(slicing)'
# f=[]
# l=['python', 'java', 'c++']
# for x  in l:
#     f.append(x[::-1])
# print(f)

'reversing string easy'
# l=['python', 'java', 'c++']
# res=[x[::-1] for x in l]
# print(res)

'printing alphabets'
# import string
# alphabet_list = list(string.ascii_lowercase)
# print(alphabet_list)
''
# alphabet_list = []
# for i in range(97, 123):
#     alphabet_list.append(chr(i))

# print(alphabet_list)

''
# k=[chr(x) for x in range(65,91)]
# print(k)
'order in given alphabt'
# g=['b']
# res=[ord(y) for y in g]
# print(res)
'give only strings in given list'
# l=['python', 'java','c++',12,2.36,2+2]
# for x in l:
#     if type(x)==str:
#         print(x)
'string to integer withot int'
# s = "python"
# num = 0
# for ch in s:
#     digit = ord(ch) - ord('0')
#     num = num * 10 + digit

# print(num)

'swapcase functionality'
# text = 'HeLlo'
# result = ""
# for ch in text:
#     if ch >= 'a' and ch <= 'z':
#         result += chr(ord(ch) - 32)
#     elif ch >= 'A' and ch <= 'Z':
#         result += chr(ord(ch) + 32)
# print(result)

'combining list into single list'
# list = [[1, 2], [3, 4], [5, 6]]
# f= []
# for x in list:
#     for y in x:
#         f.append(y)
# print(f)
''
# res=[[x,x+1]  for x in range(1,6,2)]
# print(res)

'extract  even numbers'
# list = [[2, 5], [7, 9], [12, 15]]
# even_numbers = []

# for i in list:
#     for num in i:
#         if num % 2 == 0:
#             even_numbers.append(num)
# print(even_numbers)

'Convert a=10 int data type to 10 string data type  with out using str()?'
# a = 10
# a_string = f"{a}"
# print(a_string)
# print(type(a_string))

'string to integer'
# h='123'
# ref='0123456789'
# result=0
# for x in h:
#     for y in range(len(ref)):
#         if x==ref[y]:
#             result=result*10+y
# print(result)
# print(type(result))

'give list of squares '
# squares = []
# for i in range(1, 21):
#     squares.append(i * i)
# print(squares)

m='python programming'

def fun(k):
    if k%2==0:
        return 'even'
    else:
        return 'odd'

class student:
    def method(self):
        print('class methhod')
